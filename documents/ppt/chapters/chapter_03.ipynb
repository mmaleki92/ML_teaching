# %%
from sklearn.datasets import fetch_openml 
mnist = fetch_openml('mnist_784', as_frame=False)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:91: UserWarning: A network error occurred while downloading https://openml.org/api/v1/json/data/list/data_name/mnist_784/limit/2/status/active/. Retrying...
#   warn(
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\_appmap\wrapt\wrappers.py:712, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     710         return self._self_wrapper(wrapped, instance, args, kwargs)
# --> 712     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     713             args, kwargs)
#     715 else:
#     716     # As in this case we would be dealing with a classmethod or
#     717     # staticmethod, then _self_instance will only tell us whether
#    (...)
#     726     # class type, as it reflects what they have available in the
#     727     # decoratored function.
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\_appmap\instrument.py:129, in instrument.<locals>.instrumented_fn(wrapped, instance, args, kwargs)
#     126 f = _InstrumentedFn(
#     127     wrapped, filterable.fntype, instrumented_fn, make_call_event, params
#     128 )
# --> 129 return call_instrumented(f, instance, args, kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\_appmap\instrument.py:82, in call_instrumented(f, instance, args, kwargs)
#      77 if (
#      78     (not Recorder.get_enabled())
#      79     or is_instrumentation_disabled()
#      80     or track_shallow(f.instrumented_fn)
#      81 ):
# ---> 82     return f.fn(*args, **kwargs)
#      84 with recording_disabled():
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1447, in HTTPSConnection.connect(self)
#    1445 "Connect to a host on a given (SSL) port."
# -> 1447 super().connect()
#    1449 if self._tunnel_host:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\http\client.py:941, in HTTPConnection.connect(self)
#     940 sys.audit("http.client.connect", self, self.host, self.port)
# --> 941 self.sock = self._create_connection(
#     942     (self.host,self.port), self.timeout, self.source_address)
#     943 # Might fail in OSs that don't implement TCP_NODELAY
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\socket.py:827, in create_connection(address, timeout, source_address, all_errors)
#     826 exceptions = []
# --> 827 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     828     af, socktype, proto, canonname, sa = res
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 0>()
#       1 from sklearn.datasets import fetch_openml
# ----> 2 mnist = fetch_openml('mnist_784', as_frame=False)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:882, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser)
#     876     if data_id is not None:
#     877         raise ValueError(
#     878             "Dataset data_id={} and name={} passed, but you can only "
#     879             "specify a numeric data_id or a name, not "
#     880             "both.".format(data_id, name)
#     881         )
# --> 882     data_info = _get_data_info_by_name(
#     883         name, version, data_home, n_retries=n_retries, delay=delay
#     884     )
#     885     data_id = data_info["did"]
#     886 elif data_id is not None:
#     887     # from the previous if statement, it is given that name is None
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:283, in _get_data_info_by_name(name, version, data_home, n_retries, delay)
#     281 url = _SEARCH_NAME.format(name) + "/status/active/"
#     282 error_msg = "No active dataset {} found.".format(name)
# --> 283 json_data = _get_json_content_from_openml_api(
#     284     url,
#     285     error_msg,
#     286     data_home=data_home,
#     287     n_retries=n_retries,
#     288     delay=delay,
#     289 )
#     290 res = json_data["data"]["dataset"]
#     291 if len(res) > 1:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:227, in _get_json_content_from_openml_api(url, error_message, data_home, n_retries, delay)
#     224         return json.loads(response.read().decode("utf-8"))
#     226 try:
# --> 227     return _load_json()
#     228 except HTTPError as error:
#     229     # 412 is an OpenML specific error code, indicating a generic error
#     230     # (e.g., data not found)
#     231     if error.code != 412:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:52, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      50     return f(*args, **kw)
#      51 try:
# ---> 52     return f(*args, **kw)
#      53 except URLError:
#      54     raise
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:222, in _get_json_content_from_openml_api.<locals>._load_json()
#     219 @_retry_with_clean_cache(url, data_home)
#     220 def _load_json():
#     221     with closing(
# --> 222         _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     223     ) as response:
#     224         return json.loads(response.read().decode("utf-8"))
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:154, in _open_openml_url(openml_path, data_home, n_retries, delay)
#     147 try:
#     148     # Create a tmpdir as a subfolder of dir_name where the final file will
#     149     # be moved to if the download is successful. This guarantees that the
#     150     # renaming operation to the final location is atomic to ensure the
#     151     # concurrence safety of the dataset caching mechanism.
#     152     with TemporaryDirectory(dir=dir_name) as tmpdir:
#     153         with closing(
# --> 154             _retry_on_network_error(n_retries, delay, req.full_url)(urlopen)(
#     155                 req
#     156             )
#     157         ) as fsrc:
#     158             opener: Callable
#     159             if is_gzip_encoded(fsrc):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:84, in _retry_on_network_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      82 while True:
#      83     try:
# ---> 84         return f(*args, **kwargs)
#      85     except (URLError, TimeoutError) as e:
#      86         # 412 is a specific OpenML error code.
#      87         if isinstance(e, HTTPError) and e.code == 412:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
X, y = mnist.data, mnist.target
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 0>()
# ----> 1 X, y = mnist.data, mnist.target
#       2 X
#
# NameError: name 'mnist' is not defined

# %%
X.shape (70000, 784)
y

# %%
import matplotlib.pyplot as plt

def plot_digit(image_data):
    image = image_data.reshape(28, 28)
    plt.imshow(image, cmap="binary")
    plt.axis("off")

some_digit = X[0]
plot_digit(some_digit)
plt.show()

# %%
y[0]

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %% [markdown]
# Digits from the MNIST dataset
#
# ![image.png](attachment:image.png)

# %%
y_train_5 = (y_train == '5') # True for all 5s, False for all other digits y_test_5 = (y_test == '5')
